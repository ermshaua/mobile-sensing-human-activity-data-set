# %% [markdown]
# # Data Set Exploration
# In this notebook, we explore the characteristics of the 126 MOSAD time series.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 26})

from matplotlib.cm import get_cmap
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import sys
sys.path.append("../")

from tqdm import tqdm
from itertools import product

# %%
from src.utils import load_mosad_dataset
from src.visualizer import plot_ts

# %% [markdown]
# Let's load and list the datasets.

# %%
df_ts = load_mosad_dataset()
df_ts
# Out:
#                       dataset  routine  subject  sensor  sample_rate  \
# 0     Routine1_Subject1_X-Acc        1        1   X-Acc           50
# 1    Routine1_Subject1_X-Gyro        1        1  X-Gyro           50
# 2     Routine1_Subject1_X-Mag        1        1   X-Mag           50
# 3     Routine1_Subject1_Y-Acc        1        1   Y-Acc           50
# 4    Routine1_Subject1_Y-Gyro        1        1  Y-Gyro           50
# 5     Routine1_Subject1_Y-Mag        1        1   Y-Mag           50
# 6     Routine1_Subject1_Z-Acc        1        1   Z-Acc           50
# 7    Routine1_Subject1_Z-Gyro        1        1  Z-Gyro           50
# 8     Routine1_Subject1_Z-Mag        1        1   Z-Mag           50
# 9     Routine1_Subject2_X-Acc        1        2   X-Acc           50
# 10   Routine1_Subject2_X-Gyro        1        2  X-Gyro           50
# 11    Routine1_Subject2_X-Mag        1        2   X-Mag           50
# 12    Routine1_Subject2_Y-Acc        1        2   Y-Acc           50
# 13   Routine1_Subject2_Y-Gyro        1        2  Y-Gyro           50
# 14    Routine1_Subject2_Y-Mag        1        2   Y-Mag           50
# 15    Routine1_Subject2_Z-Acc        1        2   Z-Acc           50
# 16   Routine1_Subject2_Z-Gyro        1        2  Z-Gyro           50
# 17    Routine1_Subject2_Z-Mag        1        2   Z-Mag           50
# 18    Routine1_Subject3_X-Acc        1        3   X-Acc           50
# 19   Routine1_Subject3_X-Gyro        1        3  X-Gyro           50
# 20    Routine1_Subject3_X-Mag        1        3   X-Mag           50
# 21    Routine1_Subject3_Y-Acc        1        3   Y-Acc           50
# 22   Routine1_Subject3_Y-Gyro        1        3  Y-Gyro           50
# 23    Routine1_Subject3_Y-Mag        1        3   Y-Mag           50
# 24    Routine1_Subject3_Z-Acc        1        3   Z-Acc           50
# 25   Routine1_Subject3_Z-Gyro        1        3  Z-Gyro           50
# 26    Routine1_Subject3_Z-Mag        1        3   Z-Mag           50
# 27    Routine1_Subject4_X-Acc        1        4   X-Acc           50
# 28   Routine1_Subject4_X-Gyro        1        4  X-Gyro           50
# 29    Routine1_Subject4_X-Mag        1        4   X-Mag           50
# 30    Routine1_Subject4_Y-Acc        1        4   Y-Acc           50
# 31   Routine1_Subject4_Y-Gyro        1        4  Y-Gyro           50
# 32    Routine1_Subject4_Y-Mag        1        4   Y-Mag           50
# 33    Routine1_Subject4_Z-Acc        1        4   Z-Acc           50
# 34   Routine1_Subject4_Z-Gyro        1        4  Z-Gyro           50
# 35    Routine1_Subject4_Z-Mag        1        4   Z-Mag           50
# 36    Routine1_Subject5_X-Acc        1        5   X-Acc           50
# 37   Routine1_Subject5_X-Gyro        1        5  X-Gyro           50
# 38    Routine1_Subject5_X-Mag        1        5   X-Mag           50
# 39    Routine1_Subject5_Y-Acc        1        5   Y-Acc           50
# 40   Routine1_Subject5_Y-Gyro        1        5  Y-Gyro           50
# 41    Routine1_Subject5_Y-Mag        1        5   Y-Mag           50
# 42    Routine1_Subject5_Z-Acc        1        5   Z-Acc           50
# 43   Routine1_Subject5_Z-Gyro        1        5  Z-Gyro           50
# 44    Routine1_Subject5_Z-Mag        1        5   Z-Mag           50
# 45    Routine1_Subject6_X-Acc        1        6   X-Acc           50
# 46   Routine1_Subject6_X-Gyro        1        6  X-Gyro           50
# 47    Routine1_Subject6_X-Mag        1        6   X-Mag           50
# 48    Routine1_Subject6_Y-Acc        1        6   Y-Acc           50
# 49   Routine1_Subject6_Y-Gyro        1        6  Y-Gyro           50
# 50    Routine1_Subject6_Y-Mag        1        6   Y-Mag           50
# 51    Routine1_Subject6_Z-Acc        1        6   Z-Acc           50
# 52   Routine1_Subject6_Z-Gyro        1        6  Z-Gyro           50
# 53    Routine1_Subject6_Z-Mag        1        6   Z-Mag           50
# 54    Routine2_Subject2_X-Acc        2        2   X-Acc           50
# 55   Routine2_Subject2_X-Gyro        2        2  X-Gyro           50
# 56    Routine2_Subject2_X-Mag        2        2   X-Mag           50
# 57    Routine2_Subject2_Y-Acc        2        2   Y-Acc           50
# 58   Routine2_Subject2_Y-Gyro        2        2  Y-Gyro           50
# 59    Routine2_Subject2_Y-Mag        2        2   Y-Mag           50
# 60    Routine2_Subject2_Z-Acc        2        2   Z-Acc           50
# 61   Routine2_Subject2_Z-Gyro        2        2  Z-Gyro           50
# 62    Routine2_Subject2_Z-Mag        2        2   Z-Mag           50
# 63    Routine2_Subject3_X-Acc        2        3   X-Acc           50
# 64   Routine2_Subject3_X-Gyro        2        3  X-Gyro           50
# 65    Routine2_Subject3_X-Mag        2        3   X-Mag           50
# 66    Routine2_Subject3_Y-Acc        2        3   Y-Acc           50
# 67   Routine2_Subject3_Y-Gyro        2        3  Y-Gyro           50
# 68    Routine2_Subject3_Y-Mag        2        3   Y-Mag           50
# 69    Routine2_Subject3_Z-Acc        2        3   Z-Acc           50
# 70   Routine2_Subject3_Z-Gyro        2        3  Z-Gyro           50
# 71    Routine2_Subject3_Z-Mag        2        3   Z-Mag           50
# 72    Routine2_Subject4_X-Acc        2        4   X-Acc           50
# 73   Routine2_Subject4_X-Gyro        2        4  X-Gyro           50
# 74    Routine2_Subject4_X-Mag        2        4   X-Mag           50
# 75    Routine2_Subject4_Y-Acc        2        4   Y-Acc           50
# 76   Routine2_Subject4_Y-Gyro        2        4  Y-Gyro           50
# 77    Routine2_Subject4_Y-Mag        2        4   Y-Mag           50
# 78    Routine2_Subject4_Z-Acc        2        4   Z-Acc           50
# 79   Routine2_Subject4_Z-Gyro        2        4  Z-Gyro           50
# 80    Routine2_Subject4_Z-Mag        2        4   Z-Mag           50
# 81    Routine2_Subject5_X-Acc        2        5   X-Acc           50
# 82   Routine2_Subject5_X-Gyro        2        5  X-Gyro           50
# 83    Routine2_Subject5_X-Mag        2        5   X-Mag           50
# 84    Routine2_Subject5_Y-Acc        2        5   Y-Acc           50
# 85   Routine2_Subject5_Y-Gyro        2        5  Y-Gyro           50
# 86    Routine2_Subject5_Y-Mag        2        5   Y-Mag           50
# 87    Routine2_Subject5_Z-Acc        2        5   Z-Acc           50
# 88   Routine2_Subject5_Z-Gyro        2        5  Z-Gyro           50
# 89    Routine2_Subject5_Z-Mag        2        5   Z-Mag           50
# 90    Routine3_Subject2_X-Acc        3        2   X-Acc           50
# 91   Routine3_Subject2_X-Gyro        3        2  X-Gyro           50
# 92    Routine3_Subject2_X-Mag        3        2   X-Mag           50
# 93    Routine3_Subject2_Y-Acc        3        2   Y-Acc           50
# 94   Routine3_Subject2_Y-Gyro        3        2  Y-Gyro           50
# 95    Routine3_Subject2_Y-Mag        3        2   Y-Mag           50
# 96    Routine3_Subject2_Z-Acc        3        2   Z-Acc           50
# 97   Routine3_Subject2_Z-Gyro        3        2  Z-Gyro           50
# 98    Routine3_Subject2_Z-Mag        3        2   Z-Mag           50
# 99    Routine3_Subject3_X-Acc        3        3   X-Acc           50
# 100  Routine3_Subject3_X-Gyro        3        3  X-Gyro           50
# 101   Routine3_Subject3_X-Mag        3        3   X-Mag           50
# 102   Routine3_Subject3_Y-Acc        3        3   Y-Acc           50
# 103  Routine3_Subject3_Y-Gyro        3        3  Y-Gyro           50
# 104   Routine3_Subject3_Y-Mag        3        3   Y-Mag           50
# 105   Routine3_Subject3_Z-Acc        3        3   Z-Acc           50
# 106  Routine3_Subject3_Z-Gyro        3        3  Z-Gyro           50
# 107   Routine3_Subject3_Z-Mag        3        3   Z-Mag           50
# 108   Routine3_Subject4_X-Acc        3        4   X-Acc           50
# 109  Routine3_Subject4_X-Gyro        3        4  X-Gyro           50
# 110   Routine3_Subject4_X-Mag        3        4   X-Mag           50
# 111   Routine3_Subject4_Y-Acc        3        4   Y-Acc           50
# 112  Routine3_Subject4_Y-Gyro        3        4  Y-Gyro           50
# 113   Routine3_Subject4_Y-Mag        3        4   Y-Mag           50
# 114   Routine3_Subject4_Z-Acc        3        4   Z-Acc           50
# 115  Routine3_Subject4_Z-Gyro        3        4  Z-Gyro           50
# 116   Routine3_Subject4_Z-Mag        3        4   Z-Mag           50
# 117   Routine3_Subject5_X-Acc        3        5   X-Acc           50
# 118  Routine3_Subject5_X-Gyro        3        5  X-Gyro           50
# 119   Routine3_Subject5_X-Mag        3        5   X-Mag           50
# 120   Routine3_Subject5_Y-Acc        3        5   Y-Acc           50
# 121  Routine3_Subject5_Y-Gyro        3        5  Y-Gyro           50
# 122   Routine3_Subject5_Y-Mag        3        5   Y-Mag           50
# 123   Routine3_Subject5_Z-Acc        3        5   Z-Acc           50
# 124  Routine3_Subject5_Z-Gyro        3        5  Z-Gyro           50
# 125   Routine3_Subject5_Z-Mag        3        5   Z-Mag           50
#
#                                          change_points  \
# 0    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 1    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 2    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 3    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 4    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 5    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 6    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 7    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 8    [738, 1722, 11356, 14124, 20558, 29858, 32736,...
# 9    [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 10   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 11   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 12   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 13   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 14   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 15   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 16   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 17   [928, 1652, 10952, 14086, 20136, 29236, 32502,...
# 18   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 19   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 20   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 21   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 22   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 23   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 24   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 25   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 26   [751, 1853, 10953, 13686, 19835, 28944, 31644,...
# 27   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 28   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 29   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 30   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 31   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 32   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 33   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 34   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 35   [625, 1289, 11428, 14853, 21203, 28553, 31665,...
# 36   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 37   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 38   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 39   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 40   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 41   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 42   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 43   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 44   [601, 1302, 10402, 13371, 20223, 29498, 32597,...
# 45   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 46   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 47   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 48   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 49   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 50   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 51   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 52   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 53   [868, 1835, 11570, 14778, 21287, 30679, 34019,...
# 54                                       [9018, 10519]
# 55                                       [9018, 10519]
# 56                                       [9018, 10519]
# 57                                       [9018, 10519]
# 58                                       [9018, 10519]
# 59                                       [9018, 10519]
# 60                                       [9018, 10519]
# 61                                       [9018, 10519]
# 62                                       [9018, 10519]
# 63                                       [9001, 10452]
# 64                                       [9001, 10452]
# 65                                       [9001, 10452]
# 66                                       [9001, 10452]
# 67                                       [9001, 10452]
# 68                                       [9001, 10452]
# 69                                       [9001, 10452]
# 70                                       [9001, 10452]
# 71                                       [9001, 10452]
# 72                                        [9001, 9701]
# 73                                        [9001, 9701]
# 74                                        [9001, 9701]
# 75                                        [9001, 9701]
# 76                                        [9001, 9701]
# 77                                        [9001, 9701]
# 78                                        [9001, 9701]
# 79                                        [9001, 9701]
# 80                                        [9001, 9701]
# 81                                       [9127, 10070]
# 82                                       [9127, 10070]
# 83                                       [9127, 10070]
# 84                                       [9127, 10070]
# 85                                       [9127, 10070]
# 86                                       [9127, 10070]
# 87                                       [9127, 10070]
# 88                                       [9127, 10070]
# 89                                       [9127, 10070]
# 90                   [5901, 8943, 14894, 16444, 17594]
# 91                   [5901, 8943, 14894, 16444, 17594]
# 92                   [5901, 8943, 14894, 16444, 17594]
# 93                   [5901, 8943, 14894, 16444, 17594]
# 94                   [5901, 8943, 14894, 16444, 17594]
# 95                   [5901, 8943, 14894, 16444, 17594]
# 96                   [5901, 8943, 14894, 16444, 17594]
# 97                   [5901, 8943, 14894, 16444, 17594]
# 98                   [5901, 8943, 14894, 16444, 17594]
# 99                   [6118, 9175, 15242, 16841, 18067]
# 100                  [6118, 9175, 15242, 16841, 18067]
# 101                  [6118, 9175, 15242, 16841, 18067]
# 102                  [6118, 9175, 15242, 16841, 18067]
# 103                  [6118, 9175, 15242, 16841, 18067]
# 104                  [6118, 9175, 15242, 16841, 18067]
# 105                  [6118, 9175, 15242, 16841, 18067]
# 106                  [6118, 9175, 15242, 16841, 18067]
# 107                  [6118, 9175, 15242, 16841, 18067]
# 108                  [6001, 9134, 15201, 16751, 17680]
# 109                  [6001, 9134, 15201, 16751, 17680]
# 110                  [6001, 9134, 15201, 16751, 17680]
# 111                  [6001, 9134, 15201, 16751, 17680]
# 112                  [6001, 9134, 15201, 16751, 17680]
# 113                  [6001, 9134, 15201, 16751, 17680]
# 114                  [6001, 9134, 15201, 16751, 17680]
# 115                  [6001, 9134, 15201, 16751, 17680]
# 116                  [6001, 9134, 15201, 16751, 17680]
# 117                  [6056, 9160, 15209, 16735, 17785]
# 118                  [6056, 9160, 15209, 16735, 17785]
# 119                  [6056, 9160, 15209, 16735, 17785]
# 120                  [6056, 9160, 15209, 16735, 17785]
# 121                  [6056, 9160, 15209, 16735, 17785]
# 122                  [6056, 9160, 15209, 16735, 17785]
# 123                  [6056, 9160, 15209, 16735, 17785]
# 124                  [6056, 9160, 15209, 16735, 17785]
# 125                  [6056, 9160, 15209, 16735, 17785]
#
#                                             activities  \
# 0    [descend stairs, climb stairs, vacuum, lie, ir...
# 1    [descend stairs, climb stairs, vacuum, lie, ir...
# 2    [descend stairs, climb stairs, vacuum, lie, ir...
# 3    [descend stairs, climb stairs, vacuum, lie, ir...
# 4    [descend stairs, climb stairs, vacuum, lie, ir...
# 5    [descend stairs, climb stairs, vacuum, lie, ir...
# 6    [descend stairs, climb stairs, vacuum, lie, ir...
# 7    [descend stairs, climb stairs, vacuum, lie, ir...
# 8    [descend stairs, climb stairs, vacuum, lie, ir...
# 9    [descend stairs, climb stairs, vacuum, lie, ir...
# 10   [descend stairs, climb stairs, vacuum, lie, ir...
# 11   [descend stairs, climb stairs, vacuum, lie, ir...
# 12   [descend stairs, climb stairs, vacuum, lie, ir...
# 13   [descend stairs, climb stairs, vacuum, lie, ir...
# 14   [descend stairs, climb stairs, vacuum, lie, ir...
# 15   [descend stairs, climb stairs, vacuum, lie, ir...
# 16   [descend stairs, climb stairs, vacuum, lie, ir...
# 17   [descend stairs, climb stairs, vacuum, lie, ir...
# 18   [descend stairs, climb stairs, vacuum, lie, ir...
# 19   [descend stairs, climb stairs, vacuum, lie, ir...
# 20   [descend stairs, climb stairs, vacuum, lie, ir...
# 21   [descend stairs, climb stairs, vacuum, lie, ir...
# 22   [descend stairs, climb stairs, vacuum, lie, ir...
# 23   [descend stairs, climb stairs, vacuum, lie, ir...
# 24   [descend stairs, climb stairs, vacuum, lie, ir...
# 25   [descend stairs, climb stairs, vacuum, lie, ir...
# 26   [descend stairs, climb stairs, vacuum, lie, ir...
# 27   [descend stairs, climb stairs, vacuum, lie, ir...
# 28   [descend stairs, climb stairs, vacuum, lie, ir...
# 29   [descend stairs, climb stairs, vacuum, lie, ir...
# 30   [descend stairs, climb stairs, vacuum, lie, ir...
# 31   [descend stairs, climb stairs, vacuum, lie, ir...
# 32   [descend stairs, climb stairs, vacuum, lie, ir...
# 33   [descend stairs, climb stairs, vacuum, lie, ir...
# 34   [descend stairs, climb stairs, vacuum, lie, ir...
# 35   [descend stairs, climb stairs, vacuum, lie, ir...
# 36   [descend stairs, climb stairs, vacuum, lie, ir...
# 37   [descend stairs, climb stairs, vacuum, lie, ir...
# 38   [descend stairs, climb stairs, vacuum, lie, ir...
# 39   [descend stairs, climb stairs, vacuum, lie, ir...
# 40   [descend stairs, climb stairs, vacuum, lie, ir...
# 41   [descend stairs, climb stairs, vacuum, lie, ir...
# 42   [descend stairs, climb stairs, vacuum, lie, ir...
# 43   [descend stairs, climb stairs, vacuum, lie, ir...
# 44   [descend stairs, climb stairs, vacuum, lie, ir...
# 45   [descend stairs, climb stairs, vacuum, lie, ir...
# 46   [descend stairs, climb stairs, vacuum, lie, ir...
# 47   [descend stairs, climb stairs, vacuum, lie, ir...
# 48   [descend stairs, climb stairs, vacuum, lie, ir...
# 49   [descend stairs, climb stairs, vacuum, lie, ir...
# 50   [descend stairs, climb stairs, vacuum, lie, ir...
# 51   [descend stairs, climb stairs, vacuum, lie, ir...
# 52   [descend stairs, climb stairs, vacuum, lie, ir...
# 53   [descend stairs, climb stairs, vacuum, lie, ir...
# 54                  [spin, sit-ups, modified push-ups]
# 55                  [spin, sit-ups, modified push-ups]
# 56                  [spin, sit-ups, modified push-ups]
# 57                  [spin, sit-ups, modified push-ups]
# 58                  [spin, sit-ups, modified push-ups]
# 59                  [spin, sit-ups, modified push-ups]
# 60                  [spin, sit-ups, modified push-ups]
# 61                  [spin, sit-ups, modified push-ups]
# 62                  [spin, sit-ups, modified push-ups]
# 63                  [spin, sit-ups, modified push-ups]
# 64                  [spin, sit-ups, modified push-ups]
# 65                  [spin, sit-ups, modified push-ups]
# 66                  [spin, sit-ups, modified push-ups]
# 67                  [spin, sit-ups, modified push-ups]
# 68                  [spin, sit-ups, modified push-ups]
# 69                  [spin, sit-ups, modified push-ups]
# 70                  [spin, sit-ups, modified push-ups]
# 71                  [spin, sit-ups, modified push-ups]
# 72                  [spin, sit-ups, modified push-ups]
# 73                  [spin, sit-ups, modified push-ups]
# 74                  [spin, sit-ups, modified push-ups]
# 75                  [spin, sit-ups, modified push-ups]
# 76                  [spin, sit-ups, modified push-ups]
# 77                  [spin, sit-ups, modified push-ups]
# 78                  [spin, sit-ups, modified push-ups]
# 79                  [spin, sit-ups, modified push-ups]
# 80                  [spin, sit-ups, modified push-ups]
# 81                  [spin, sit-ups, modified push-ups]
# 82                  [spin, sit-ups, modified push-ups]
# 83                  [spin, sit-ups, modified push-ups]
# 84                  [spin, sit-ups, modified push-ups]
# 85                  [spin, sit-ups, modified push-ups]
# 86                  [spin, sit-ups, modified push-ups]
# 87                  [spin, sit-ups, modified push-ups]
# 88                  [spin, sit-ups, modified push-ups]
# 89                  [spin, sit-ups, modified push-ups]
# 90   [slow walk, run, walk, rope jump, squat, jumpi...
# 91   [slow walk, run, walk, rope jump, squat, jumpi...
# 92   [slow walk, run, walk, rope jump, squat, jumpi...
# 93   [slow walk, run, walk, rope jump, squat, jumpi...
# 94   [slow walk, run, walk, rope jump, squat, jumpi...
# 95   [slow walk, run, walk, rope jump, squat, jumpi...
# 96   [slow walk, run, walk, rope jump, squat, jumpi...
# 97   [slow walk, run, walk, rope jump, squat, jumpi...
# 98   [slow walk, run, walk, rope jump, squat, jumpi...
# 99   [slow walk, run, walk, rope jump, squat, jumpi...
# 100  [slow walk, run, walk, rope jump, squat, jumpi...
# 101  [slow walk, run, walk, rope jump, squat, jumpi...
# 102  [slow walk, run, walk, rope jump, squat, jumpi...
# 103  [slow walk, run, walk, rope jump, squat, jumpi...
# 104  [slow walk, run, walk, rope jump, squat, jumpi...
# 105  [slow walk, run, walk, rope jump, squat, jumpi...
# 106  [slow walk, run, walk, rope jump, squat, jumpi...
# 107  [slow walk, run, walk, rope jump, squat, jumpi...
# 108  [slow walk, run, walk, rope jump, squat, jumpi...
# 109  [slow walk, run, walk, rope jump, squat, jumpi...
# 110  [slow walk, run, walk, rope jump, squat, jumpi...
# 111  [slow walk, run, walk, rope jump, squat, jumpi...
# 112  [slow walk, run, walk, rope jump, squat, jumpi...
# 113  [slow walk, run, walk, rope jump, squat, jumpi...
# 114  [slow walk, run, walk, rope jump, squat, jumpi...
# 115  [slow walk, run, walk, rope jump, squat, jumpi...
# 116  [slow walk, run, walk, rope jump, squat, jumpi...
# 117  [slow walk, run, walk, rope jump, squat, jumpi...
# 118  [slow walk, run, walk, rope jump, squat, jumpi...
# 119  [slow walk, run, walk, rope jump, squat, jumpi...
# 120  [slow walk, run, walk, rope jump, squat, jumpi...
# 121  [slow walk, run, walk, rope jump, squat, jumpi...
# 122  [slow walk, run, walk, rope jump, squat, jumpi...
# 123  [slow walk, run, walk, rope jump, squat, jumpi...
# 124  [slow walk, run, walk, rope jump, squat, jumpi...
# 125  [slow walk, run, walk, rope jump, squat, jumpi...
#
#                                            time_series
# 0    [-0.1986, -0.454326, -0.5473, -0.496056, -0.48...
# 1    [0.0174, 0.0358, 0.0431, 0.0358, 0.0168, 0.008...
# 2    [-31.02, -30.84, -30.65, -30.58, -31.52, -30.7...
# 3    [-0.0161, -0.100877, -0.1434, -0.13972, -0.081...
# 4    [-0.0525, -0.0568, -0.0482, -0.0012, 0.0153, 0...
# 5    [-127.26, -127.41, -127.86, -127.23, -127.27, ...
# 6    [0.0865, 0.106412, 0.0107, -0.143706, -0.2007,...
# 7    [0.0509, 0.0851, 0.1157, 0.1291, 0.1193, 0.114...
# 8    [-78.8, -78.16, -78.93, -79.72, -79.14, -78.78...
# 9    [-0.0098, 0.0536, 0.1473, 0.1691, -0.0239, -0....
# 10   [0.135, 0.1387, 0.1418, 0.137661, 0.0941, 0.07...
# 11   [-82.002, -81.980404, -81.964339, -81.957, -81...
# 12   [-0.006, 0.0283, 0.1822, 0.3, 0.4181, 0.4688, ...
# 13   [0.0973, 0.0967, 0.101, 0.108797, 0.1242, 0.11...
# 14   [13.209, 13.0524, 12.781145, 12.519, 12.370924...
# 15   [-0.4926, -0.6312, -0.6055, -0.731, -0.7364, -...
# 16   [-0.0443, -0.0675, -0.0901, -0.114192, -0.1256...
# 17   [-15.22, -15.469665, -15.77818, -16.026, -16.1...
# 18   [-0.0951, 0.1555, 0.302, -0.8649, -1.7836, -2....
# 19   [-0.4633, -0.482055, -0.556583, -0.607576, -0....
# 20   [-45.651, -45.964, -45.962, -45.763, -45.408, ...
# 21   [-0.6936, -1.1266, -1.2025, -0.7343, 0.1472, 0...
# 22   [0.1353, -0.040883, -0.129054, -0.181074, -0.2...
# 23   [26.714, 25.423, 24.067, 22.586, 21.071, 19.67...
# 24   [-0.7502, -0.9234, -1.021, -0.7898, -0.4792, -...
# 25   [-0.3353, -0.337485, -0.28888, -0.244829, -0.1...
# 26   [105.051, 105.234, 105.553, 105.966, 106.43, 1...
# 27   [-0.5731, -0.4151, -0.4151, -0.4151, 0.0147, 0...
# 28   [-0.0288, -0.0478, -0.0539, -0.044017, -0.0293...
# 29   [24.749, 24.879936, 25.002586, 25.201, 25.356,...
# 30   [0.0435, -0.1374, -0.1374, -0.1374, 0.1321, 0....
# 31   [0.2107, 0.2583, 0.287, 0.293786, 0.293203, 0....
# 32   [57.692, 57.703761, 57.72083, 57.756, 57.768, ...
# 33   [-0.2388, -0.2916, -0.2916, -0.2916, -0.1454, ...
# 34   [0.0292, 0.0219, 0.0048, -0.006781, 0.006031, ...
# 35   [-25.826, -25.675463, -25.516147, -25.24, -25....
# 36   [0.132, 0.132, 0.132, 0.1684, 0.1684, 0.1684, ...
# 37   [-0.0714, -0.0757, -0.0775, -0.0714, -0.0659, ...
# 38   [76.815, 77.949955, 79.223358, 79.740125, 80.7...
# 39   [-0.0225, -0.0225, -0.0225, 0.0412, 0.0412, 0....
# 40   [0.1653, 0.1647, 0.1555, 0.1409, 0.1225, 0.109...
# 41   [-109.424, -108.94959, -108.356598, -108.10126...
# 42   [-0.0298, -0.0298, -0.0298, 0.0506, 0.0506, 0....
# 43   [0.0292, 0.0176, 0.0097, 0.0066, 0.0109, 0.013...
# 44   [-308.964, -308.847563, -308.73168, -308.68873...
# 45   [2.2806, 1.78743, 1.3025, 1.1769, 0.642, -0.46...
# 46   [-0.2335, -0.4051, -0.5585, -0.8266, -1.1425, ...
# 47   [19.92, 20.55, 19.71, 19.58, 18.31, 17.21, 16....
# 48   [0.6798, 0.166365, -0.4266, -1.1819, -0.8857, ...
# 49   [-0.0376, -0.1152, -0.0486, -0.2282, -0.4285, ...
# 50   [43.24, 42.64, 43.38, 44.59, 45.31, 44.64, 44....
# 51   [-1.3262, -1.741762, -1.8214, -2.0568, -1.6449...
# 52   [-0.1725, -0.1505, -0.2801, -0.4401, -0.6099, ...
# 53   [-53.54, -53.51, -53.09, -51.39, -50.05, -49.1...
# 54   [-0.6189, -0.572264, -0.562772, -0.5648, -0.64...
# 55   [0.0821, 0.1402, 0.2018, 0.2599, 0.3784, 0.431...
# 56   [-7.609, -7.927, -8.473, -9.245, -10.173, -11....
# 57   [0.1304, 0.219328, 0.380045, 0.4332, 0.668816,...
# 58   [0.0838, 0.1443, 0.2109, 0.2647, 0.3532, 0.360...
# 59   [95.283, 95.624, 96.205, 97.043, 98.123, 99.69...
# 60   [0.5327, 0.538034, 0.698363, 0.7618, 0.974558,...
# 61   [0.0139, 0.0243, 0.0481, 0.0798, 0.1367, 0.211...
# 62   [205.988, 205.818, 205.526, 205.098, 204.539, ...
# 63   [-0.4281, -0.7344, -1.1427, -0.9542, -0.4243, ...
# 64   [0.1146, 0.0664, 0.07, 0.072134, 0.0505, 0.016...
# 65   [-13.505, -13.406932, -13.325603, -13.234, -13...
# 66   [-0.562, -0.4176, -0.188, 0.0498, 0.0893, -0.0...
# 67   [-0.1012, -0.0688, -0.037, -0.024689, -0.0175,...
# 68   [55.165, 55.212192, 55.247126, 55.285, 55.3496...
# 69   [-0.5628, -0.4867, -0.4186, -0.5026, -0.4307, ...
# 70   [0.0726, 0.0512, 0.0836, 0.11379, 0.1313, 0.11...
# 71   [15.274, 15.191439, 15.134894, 15.075, 14.9920...
# 72   [0.173, 0.1537, 0.1637, -0.0014, -0.042661, -0...
# 73   [-0.018, -0.0137, -0.0137, -0.0046, 0.0229, 0....
# 74   [-22.226, -22.34, -22.448, -22.554, -22.656, -...
# 75   [-0.0827, -0.1042, -0.0777, 0.0384, 0.095202, ...
# 76   [-0.1245, -0.1428, -0.1593, -0.1679, -0.1618, ...
# 77   [37.478, 37.438, 37.403, 37.37, 37.337, 37.293...
# 78   [-0.0299, -0.0232, -0.1301, -0.1068, 0.063206,...
# 79   [-0.107, -0.0875, -0.0795, -0.0734, -0.0667, -...
# 80   [-13.297, -13.218, -13.135, -13.047, -12.966, ...
# 81   [0.0318, 0.0318, -0.0152, -0.0152, -0.0152, -0...
# 82   [-0.0108, -0.0108, -0.007568, -0.004905, -0.00...
# 83   [25.033, 25.069, 25.098, 25.124, 25.157, 25.19...
# 84   [0.011, 0.011, 0.0438, 0.0438, 0.0438, -0.0105...
# 85   [-0.0134, -0.0122, -0.007856, -0.010761, -0.01...
# 86   [69.887, 69.872, 69.86, 69.852, 69.842, 69.832...
# 87   [0.0003, 0.0003, -0.0159, -0.0159, -0.0159, 0....
# 88   [0.024, 0.0215, 0.019656, 0.020111, 0.0215, 0....
# 89   [36.687, 36.691, 36.693, 36.692, 36.688, 36.68...
# 90   [6.9871, 5.9521, 2.6068, 0.0953, -1.4312, -2.6...
# 91   [-1.0028, -0.7713, -0.5019, -0.3742, -0.3162, ...
# 92   [8.687, 8.741498, 8.515, 8.237, 7.999, 7.903, ...
# 93   [2.4665, 3.4322, 2.9303, 1.1303, -0.6618, -1.6...
# 94   [-2.1648, -1.8014, -1.4257, -1.3792, -1.4556, ...
# 95   [34.76, 34.670624, 34.65, 34.704, 34.767, 34.8...
# 96   [2.4249, 2.4533, 2.5437, 2.3457, 2.4144, 2.452...
# 97   [-0.2674, -0.7408, -1.0365, -1.0603, -1.0383, ...
# 98   [16.247, 16.407587, 16.569, 16.598, 16.581, 16...
# 99   [-0.084, -0.0644, -0.3484, 0.0316, 0.2395, 0.4...
# 100  [0.1242, 0.1004, 0.064829, 0.041278, 0.082064,...
# 101  [-211.874, -211.110709, -211.743, -212.617, -2...
# 102  [0.0456, -0.0444, 0.0053, 0.5661, 0.8777, 0.74...
# 103  [-0.1805, 0.1194, 0.168843, 0.220194, 0.237296...
# 104  [67.073, 67.515677, 67.631, 67.444, 67.332, 67...
# 105  [0.0109, -0.3367, -0.0711, 0.2222, 0.5756, 0.5...
# 106  [-0.026, -0.0779, -0.100205, -0.070784, -0.043...
# 107  [221.772, 222.365261, 221.728, 220.947, 219.93...
# 108  [0.8348, 0.1522, -0.0901, 0.2965, 0.5086, 0.32...
# 109  [0.4129, 0.3848, 0.3738, 0.3353, 0.3378, 0.382...
# 110  [28.97, 28.82, 29.13575, 29.39, 30.26, 30.5, 3...
# 111  [0.4129, 0.2621, 0.2807, 0.123, -0.1723, -0.61...
# 112  [-0.0309, -0.0389, -0.0242, 0.0161, 0.0045, -0...
# 113  [76.58, 76.42, 76.280698, 75.99, 76.02, 76.49,...
# 114  [-0.8083, -1.2995, -1.1444, -0.7946, -0.1333, ...
# 115  [0.0228, 0.1493, 0.2605, 0.3075, 0.3191, 0.329...
# 116  [21.09, 21.4, 21.850408, 20.18, 20.07, 19.61, ...
# 117  [-0.0639, 0.3206, 0.3206, 0.3206, 0.9849, 0.98...
# 118  [-0.0313, -0.01839, -0.00324, 0.017, 0.027234,...
# 119  [19.51, 19.18, 19.13, 20.39, 19.93, 20.31, 19....
# 120  [-0.0043, 0.2386, 0.2386, 0.2386, 0.1689, 0.16...
# 121  [0.0923, 0.137903, 0.118283, 0.0465, -0.035871...
# 122  [187.01, 187.93, 187.78, 185.81, 185.66, 186.5...
# 123  [0.0949, 0.4038, 0.4038, 0.4038, 0.418, 0.418,...
# 124  [-0.1484, -0.128387, -0.098542, -0.0622, -0.04...
# 125  [104.53, 103.88, 102.94, 103.65, 102.54, 103.1...

# %% [markdown]
# Let's visualize by time series length, activity length and amount of change points.

# %%
fontsize = 24
_, ax = plt.subplots(1, figsize=(3,5))

df_len = pd.DataFrame()
df_len["routine"] = df_ts.routine
df_len["tslen"] = df_ts.time_series.apply(len)

groups = [df_len[df_len.routine == idx].tslen for idx in range(1, 3+1)]

ax.boxplot(groups)

ax.set_xlabel("Routine", fontsize=fontsize)
ax.set_ylabel("TS length (in minutes)", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

ax.set_yticks(np.arange(10_000, 60_000+1, 10_000))
ax.set_yticklabels(labels=[f"{round((x / 50) / 60, 1)}" for x in np.arange(10_000, 60_000+1, 10_000)])

plt.savefig(f"../figures/ts_length.pdf", bbox_inches="tight")

# %%
fontsize = 24

activity_lengths = dict()

for _, row in df_ts.iterrows():
    cps = [0] + row.change_points.tolist() + [row.time_series.shape[0]]
    alens = np.diff(cps)
    
    for a, alen in zip(row.activities, alens):
        if a not in activity_lengths:
            activity_lengths[a] = list()
            
        activity_lengths[a].append(alen)
        
activities, alens = np.array(list(activity_lengths.keys())), np.array(list(activity_lengths.values()))
idxsort = np.argsort([np.median(x) for x in alens])

_, ax = plt.subplots(1, figsize=(7,5))
# ax.scatter(np.arange(len(activity_lengths)), np.sort(activity_lengths))
ax.boxplot(alens[idxsort])

ax.set_xlabel("Activity", fontsize=fontsize)
ax.set_ylabel("Activity length (in seconds)", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

ax.set_xticklabels(activities[idxsort], rotation=90, fontsize=14)

ax.set_yticks(np.arange(2_000, 10_000+1, 2_000))
ax.set_yticklabels(labels=[f"{int(x/50)}" for x in np.arange(2_000, 10_000+1, 2_000)])
    
plt.savefig(f"../figures/activity_length.pdf", bbox_inches="tight")
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_40199/2682236030.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   activities, alens = np.array(list(activity_lengths.keys())), np.array(list(activity_lengths.values()))

# %%
fontsize = 24

change_points, counts = np.unique(df_ts["change_points"].apply(len), return_counts=True)
_, ax = plt.subplots(1, figsize=(5,5))
ax.bar(change_points, counts, width=.5)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
print(dict(zip(change_points, counts)))

ax.set_xlabel("amount of change points", fontsize=fontsize)
ax.set_ylabel("amount of time series", fontsize=fontsize)

plt.show()
# Out:
# {2: 36, 5: 36, 12: 54}

# %% [markdown]
# Lastly, let's plot example sensor recordings.

# %%
fontsize = 24
selections = [9, 54, 90]
routines = ["Household", "Sport (indoor)", "Sport (outdoor)"]

cmap = get_cmap("tab20") 
colors = cmap.colors
activity_colours = {a : colors[idx] for idx, a in enumerate(sorted(activities))}

fig, axes = plt.subplots(len(selections), sharex=True, gridspec_kw={'hspace': .1}, figsize=(20, len(selections)*2))

for idx, ax in zip(selections, axes):
    row = df_ts.iloc[idx,:]
    
    segments = [0] + row.change_points.tolist() + [row.time_series.shape[0]]
    
    for kdx in np.arange(0, len(segments)-1):
        ax.plot(np.arange(segments[kdx], segments[kdx+1]), row.time_series[segments[kdx]:segments[kdx+1]], c=activity_colours[df_ts.iloc[idx].activities[kdx]])
        
    ax.set_title(routines[row.routine-1], fontsize=fontsize)
    ax.set_facecolor('white')
    
    ax.set_ylabel(row.sensor, fontsize=fontsize)
    
    ax.set_xticks(np.arange(0, 60_000+1, 10_000))
    ax.set_xticklabels(labels=[f"{round((x / row.sample_rate) / 60, 1)}m" for x in np.arange(0, 60_000+1, 10_000)])
    
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize)

    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize)

plt.savefig(f"../figures/ts_example.pdf", bbox_inches="tight")
